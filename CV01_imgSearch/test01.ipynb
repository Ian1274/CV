# %%
import cv2
import numpy as np
import glob
import matplotlib.pyplot as plt

# %%
img_path = "selected_imgs/1.jpg"

# %%
# img = plt.imread(img_path)
img = cv2.imread(img_path)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
